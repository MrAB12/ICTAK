# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %% [markdown]
# 1. Read the dataset to python environment.

# %%
iris_data=pd.read_excel('/content/iris.xls')

# %% [markdown]
# 2. Display the columns in the dataset

# %%
iris_data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# 3. Calculate the mean of each column of the dataset.

# %%
iris_data.mean()
# Out:
# <ipython-input-7-c09e935f0978>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   iris_data.mean()
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# 4. Check for the null values present in the dataset.

# %%
iris_data.isnull().values.any()
# Out:
# False

# %% [markdown]
# 5. Perform meaningful visualizations using the dataset. Bring at least 3
# visualizations.

# %%
sn.countplot(x='Classification',data=iris_data,color='Red')
# Out:
# <Axes: xlabel='Classification', ylabel='count'>

# %%
df = iris_data.drop('Classification',axis=1)

# %%
sn.heatmap(df.corr(),annot=True,cmap='viridis')
# Out:
# <Axes: >

# %%
sn.pairplot(iris_data,hue='Classification',diag_kind='hist')

# %%
plt.boxplot(iris_data['SL'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7bac651779a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7bac65175810>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7bac65176dd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7bac65174a30>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7bac65175b70>],
#  'means': []}
